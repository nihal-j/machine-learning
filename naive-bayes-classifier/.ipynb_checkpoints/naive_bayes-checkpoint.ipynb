# %%
import numpy as np
import pickle

# %%
# load the data from the pickle file

data_file = open('data/data.pickle', 'rb')
data_org = pickle.load(data_file)

# %%
def preprocess(string):
    
    delimiters = [',', ';', '!', '.', '\"' ,'\'', '?', '-', '$', ')', '(', '#', '[', ']',
                  '+', '&', '%', '@', '*', '/']
    
    stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", 
                  "you", "your", "yours", "yourself", "yourselves", "he", "him",
                  "his", "himself", "she", "her", "hers", "herself", "it", "its",
                  "itself", "they", "them", "their", "theirs", "themselves", "what",
                  "which", "who", "whom", "this", "that", "these", "those", "am", "is",
                  "are", "was", "were", "be", "been", "being", "have", "has", "had",
                  "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but",
                  "if", "or", "because", "as", "until", "while", "of", "at", "by", "for",
                  "with", "about", "against", "between", "into", "through", "during",
                  "before", "after", "above", "below", "to", "from", "up", "down", "in",
                  "out", "on", "off", "over", "under", "again", "further", "then", "once",
                  "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
                  "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only",
                  "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just",
                  "don", "should", "now"]
    
    string = string.casefold()
    
    for d in delimiters:
        string = string.replace(d, '')
    for s in stop_words:
        string = string.replace(s+' ', '')
        string = string.replace(' '+s, '')
    string = string.split()
    
    return string

# %%
data = []

for i in range(len(data_org)):
    print('Before: ', data_org[i][0])
    data.append([preprocess(data_org[i][0]), data_org[i][1]])
    print('After: ', data[i][0])
# Out:
# Before:  So there is no way for me to plug it in here in the US unless I go by a converter.
# After:  ['so', 'there', 'is', 'no', 'way', 'for', 'me', 'to', 'plug', 'it', 'in', 'here', 'in', 'the', 'us', 'unless', 'i', 'go', 'by', 'a', 'converter']
# Before:  Good case, Excellent value.
# After:  ['good', 'case', 'excellent', 'value']
# Before:  Great for the jawbone.
# After:  ['great', 'for', 'the', 'jawbone']
# Before:  Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!
# After:  ['tied', 'to', 'charger', 'for', 'conversations', 'lasting', 'more', 'than', '45', 'minutesmajor', 'problems']
# Before:  The mic is great.
# After:  ['the', 'mic', 'is', 'great']
# Before:  I have to jiggle the plug to get it to line up right to get decent volume.
# After:  ['i', 'have', 'to', 'jiggle', 'the', 'plug', 'to', 'get', 'it', 'to', 'line', 'up', 'right', 'to', 'get', 'decent', 'volume']
# Before:  If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.
# After:  ['if', 'you', 'have', 'several', 'dozen', 'or', 'several', 'hundred', 'contacts', 'then', 'imagine', 'the', 'fun', 'of', 'sending', 'each', 'of', 'them', 'one', 'by', 'one']
# Before:  If you are Razr owner...you must have this!
# After:  ['if', 'you', 'are', 'razr', 'owneryou', 'must', 'have', 'this']
# Before:  Needless to say, I wasted my money.
# After:  ['needless', 'to', 'say', 'i', 'wasted', 'my', 'money']
# Before:  What a waste of money and time!.
# After:  ['what', 'a', 'waste', 'of', 'money', 'and', 'time']
# Before:  And the sound quality is great.
# After:  ['and', 'the', 'sound', 'quality', 'is', 'great']
# Before:  He was very impressed when going from the original battery to the extended battery.
# After:  ['he', 'was', 'very', 'impressed', 'when', 'going', 'from', 'the', 'original', 'battery', 'to', 'the', 'extended', 'battery']
# Before:  If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset.
# After:  ['if', 'the', 'two', 'were', 'seperated', 'by', 'a', 'mere', '5', 'ft', 'i', 'started', 'to', 'notice', 'excessive', 'static', 'and', 'garbled', 'sound', 'from', 'the', 'headset']
# Before:  Very good quality though
# After:  ['very', 'good', 'quality', 'though']
# Before:  The design is very odd, as the ear "clip" is not very comfortable at all.
# After:  ['the', 'design', 'is', 'very', 'odd', 'as', 'the', 'ear', 'clip', 'is', 'not', 'very', 'comfortable', 'at', 'all']
# Before:  Highly recommend for any one who has a blue tooth phone.
# After:  ['highly', 'recommend', 'for', 'any', 'one', 'who', 'has', 'a', 'blue', 'tooth', 'phone']
# Before:  I advise EVERYONE DO NOT BE FOOLED!
# After:  ['i', 'advise', 'everyone', 'do', 'not', 'be', 'fooled']
# Before:  So Far So Good!.
# After:  ['so', 'far', 'so', 'good']
# Before:  Works great!.
# After:  ['works', 'great']
# Before:  It clicks into place in a way that makes you wonder how long that mechanism would last.
# After:  ['it', 'clicks', 'into', 'place', 'in', 'a', 'way', 'that', 'makes', 'you', 'wonder', 'how', 'long', 'that', 'mechanism', 'would', 'last']
# Before:  I went on Motorola's website and followed all directions, but could not get it to pair again.
# After:  ['i', 'went', 'on', 'motorolas', 'website', 'and', 'followed', 'all', 'directions', 'but', 'could', 'not', 'get', 'it', 'to', 'pair', 'again']
# Before:  I bought this to use with my Kindle Fire and absolutely loved it!
# After:  ['i', 'bought', 'this', 'to', 'use', 'with', 'my', 'kindle', 'fire', 'and', 'absolutely', 'loved', 'it']
# Before:  The commercials are the most misleading.
# After:  ['the', 'commercials', 'are', 'the', 'most', 'misleading']
# Before:  I have yet to run this new battery below two bars and that's three days without charging.
# After:  ['i', 'have', 'yet', 'to', 'run', 'this', 'new', 'battery', 'below', 'two', 'bars', 'and', 'thats', 'three', 'days', 'without', 'charging']
# Before:  I bought it for my mother and she had a problem with the battery.
# After:  ['i', 'bought', 'it', 'for', 'my', 'mother', 'and', 'she', 'had', 'a', 'problem', 'with', 'the', 'battery']
# Before:  Great Pocket PC / phone combination.
# After:  ['great', 'pocket', 'pc', 'phone', 'combination']
# Before:  I've owned this phone for 7 months now and can say that it's the best mobile phone I've had.
# After:  ['ive', 'owned', 'this', 'phone', 'for', '7', 'months', 'now', 'and', 'can', 'say', 'that', 'its', 'the', 'best', 'mobile', 'phone', 'ive', 'had']
# Before:  I didn't think that the instructions provided were helpful to me.
# After:  ['i', 'didnt', 'think', 'that', 'the', 'instructions', 'provided', 'were', 'helpful', 'to', 'me']
# Before:  People couldnt hear me talk and I had to pull out the earphone and talk on the phone.
# After:  ['people', 'couldnt', 'hear', 'me', 'talk', 'and', 'i', 'had', 'to', 'pull', 'out', 'the', 'earphone', 'and', 'talk', 'on', 'the', 'phone']
# Before:  Doesn't hold charge.
# After:  ['doesnt', 'hold', 'charge']
# Before:  This is a simple little phone to use, but the breakage is unacceptible.
# After:  ['this', 'is', 'a', 'simple', 'little', 'phone', 'to', 'use', 'but', 'the', 'breakage', 'is', 'unacceptible']
# Before:  This product is ideal for people like me whose ears are very sensitive.
# After:  ['this', 'product', 'is', 'ideal', 'for', 'people', 'like', 'me', 'whose', 'ears', 'are', 'very', 'sensitive']
# Before:  It is unusable in a moving car at freeway speed.
# After:  ['it', 'is', 'unusable', 'in', 'a', 'moving', 'car', 'at', 'freeway', 'speed']
# Before:  I have two more years left in this contract and I hate this phone.
# After:  ['i', 'have', 'two', 'more', 'years', 'left', 'in', 'this', 'contract', 'and', 'i', 'hate', 'this', 'phone']
# Before:  Car charger as well as AC charger are included to make sure you never run out of juice.Highy recommended
# After:  ['car', 'charger', 'as', 'well', 'as', 'ac', 'charger', 'are', 'included', 'to', 'make', 'sure', 'you', 'never', 'run', 'out', 'of', 'juicehighy', 'recommended']
# Before:  You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short.
# After:  ['you', 'need', 'at', 'least', '3', 'mins', 'to', 'get', 'to', 'your', 'phone', 'book', 'from', 'the', 'time', 'you', 'first', 'turn', 'on', 'the', 'phonebattery', 'life', 'is', 'short']
# Before:  It has kept up very well.
# After:  ['it', 'has', 'kept', 'up', 'very', 'well']
# Before:  Poor Talk Time Performance.
# After:  ['poor', 'talk', 'time', 'performance']
# Before:  The case is great and works fine with the 680.
# After:  ['the', 'case', 'is', 'great', 'and', 'works', 'fine', 'with', 'the', '680']
# Before:  worthless product.
# After:  ['worthless', 'product']
# Before:  It has a great camera thats 2MP, and the pics are nice and clear with great picture quality.
# After:  ['it', 'has', 'a', 'great', 'camera', 'thats', '2mp', 'and', 'the', 'pics', 'are', 'nice', 'and', 'clear', 'with', 'great', 'picture', 'quality']
# Before:  I was not impressed by this product.
# After:  ['i', 'was', 'not', 'impressed', 'by', 'this', 'product']
# Before:  Nice headset priced right.
# After:  ['nice', 'headset', 'priced', 'right']
# Before:  I only hear garbage for audio.
# After:  ['i', 'only', 'hear', 'garbage', 'for', 'audio']
# Before:  Excellent bluetooth headset.
# After:  ['excellent', 'bluetooth', 'headset']
# Before:  It has all the features I want
# After:  ['it', 'has', 'all', 'the', 'features', 'i', 'want']
# Before:  Who in their right mind is gonna buy this battery?.
# After:  ['who', 'in', 'their', 'right', 'mind', 'is', 'gonna', 'buy', 'this', 'battery']
# Before:  AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS.
# After:  ['after', 'arguing', 'with', 'verizon', 'regarding', 'the', 'dropped', 'calls', 'we', 'returned', 'the', 'phones', 'after', 'two', 'days']
# Before:  This case seems well made.
# After:  ['this', 'case', 'seems', 'well', 'made']
# Before:  Disappointed with battery.
# After:  ['disappointed', 'with', 'battery']
# Before:  Not loud enough and doesn't turn on like it should.
# After:  ['not', 'loud', 'enough', 'and', 'doesnt', 'turn', 'on', 'like', 'it', 'should']
# Before:  good protection and does not make phone too bulky.
# After:  ['good', 'protection', 'and', 'does', 'not', 'make', 'phone', 'too', 'bulky']
# Before:  A usable keyboard actually turns a PDA into a real-world useful machine instead of just a neat gadget.
# After:  ['a', 'usable', 'keyboard', 'actually', 'turns', 'a', 'pda', 'into', 'a', 'realworld', 'useful', 'machine', 'instead', 'of', 'just', 'a', 'neat', 'gadget']
# Before:  This phone is pretty sturdy and I've never had any large problems with it.
# After:  ['this', 'phone', 'is', 'pretty', 'sturdy', 'and', 'ive', 'never', 'had', 'any', 'large', 'problems', 'with', 'it']
# Before:  I love this thing!
# After:  ['i', 'love', 'this', 'thing']
# Before:  Everything about it is fine and reasonable for the price i.e.
# After:  ['everything', 'about', 'it', 'is', 'fine', 'and', 'reasonable', 'for', 'the', 'price', 'ie']
# Before:  VERY DISAPPOINTED.
# After:  ['very', 'disappointed']
# Before:  I even dropped this phone into a stream and it was submerged for 15 seconds and it still works great!
# After:  ['i', 'even', 'dropped', 'this', 'phone', 'into', 'a', 'stream', 'and', 'it', 'was', 'submerged', 'for', '15', 'seconds', 'and', 'it', 'still', 'works', 'great']
# Before:  I have been very happy with the 510 and have had NO complaints from any one regarding my sound quality on their end.
# After:  ['i', 'have', 'been', 'very', 'happy', 'with', 'the', '510', 'and', 'have', 'had', 'no', 'complaints', 'from', 'any', 'one', 'regarding', 'my', 'sound', 'quality', 'on', 'their', 'end']
# Before:  The buttons for on and off are bad.
# After:  ['the', 'buttons', 'for', 'on', 'and', 'off', 'are', 'bad']
# Before:  Essentially you can forget Microsoft's tech support.
# After:  ['essentially', 'you', 'can', 'forget', 'microsofts', 'tech', 'support']
# Before:  I really recommend this faceplates since it looks very nice, elegant and cool.
# After:  ['i', 'really', 'recommend', 'this', 'faceplates', 'since', 'it', 'looks', 'very', 'nice', 'elegant', 'and', 'cool']
# Before:  These headphones were a great find - and I think they are perhaps the best purchase I've made in the last several years - seriously.
# After:  ['these', 'headphones', 'were', 'a', 'great', 'find', 'and', 'i', 'think', 'they', 'are', 'perhaps', 'the', 'best', 'purchase', 'ive', 'made', 'in', 'the', 'last', 'several', 'years', 'seriously']
# Before:  Buy a different phone - but not this.
# After:  ['buy', 'a', 'different', 'phone', 'but', 'not', 'this']
# Before:  You have to hold the phone at a particular angle for the other party to hear you clearly.
# After:  ['you', 'have', 'to', 'hold', 'the', 'phone', 'at', 'a', 'particular', 'angle', 'for', 'the', 'other', 'party', 'to', 'hear', 'you', 'clearly']
# Before:  The one big drawback of the MP3 player is that the buttons on the phone's front cover that let you pause and skip songs lock out after a few seconds.
# After:  ['the', 'one', 'big', 'drawback', 'of', 'the', 'mp3', 'player', 'is', 'that', 'the', 'buttons', 'on', 'the', 'phones', 'front', 'cover', 'that', 'let', 'you', 'pause', 'and', 'skip', 'songs', 'lock', 'out', 'after', 'a', 'few', 'seconds']
# Before:  A week later after I activated it, it suddenly died.
# After:  ['a', 'week', 'later', 'after', 'i', 'activated', 'it', 'it', 'suddenly', 'died']
# Before:  It feels more comfortable than most headsets because I wear glasses and that gets in the way sometimes.
# After:  ['it', 'feels', 'more', 'comfortable', 'than', 'most', 'headsets', 'because', 'i', 'wear', 'glasses', 'and', 'that', 'gets', 'in', 'the', 'way', 'sometimes']
# Before:  Great for iPODs too.
# After:  ['great', 'for', 'ipods', 'too']
# Before:  This device is great in several situations:1.)
# After:  ['this', 'device', 'is', 'great', 'in', 'several', 'situations:1']
# Before:  Mic Doesn't work.
# After:  ['mic', 'doesnt', 'work']
# Before:  Even in my BMW 3 series which is fairly quiet, I have trouble hearing what the other person is saying.
# After:  ['even', 'in', 'my', 'bmw', '3', 'series', 'which', 'is', 'fairly', 'quiet', 'i', 'have', 'trouble', 'hearing', 'what', 'the', 'other', 'person', 'is', 'saying']
# Before:  Great choice!
# After:  ['great', 'choice']
# Before:  Nice docking station for home or work.
# After:  ['nice', 'docking', 'station', 'for', 'home', 'or', 'work']
# Before:  This is a beautiful phone.
# After:  ['this', 'is', 'a', 'beautiful', 'phone']
# Before:  Love this product.
# After:  ['love', 'this', 'product']
# Before:  Do Not Buy for D807...wrongly advertised for D807.
# After:  ['do', 'not', 'buy', 'for', 'd807wrongly', 'advertised', 'for', 'd807']
# Before:  This is a great little item.
# After:  ['this', 'is', 'a', 'great', 'little', 'item']
# Before:  I love this phone , It is very handy and has a lot of features .
# After:  ['i', 'love', 'this', 'phone', 'it', 'is', 'very', 'handy', 'and', 'has', 'a', 'lot', 'of', 'features']
# Before:  I purchased this and within 2 days it was no longer working!!!!!!!!!
# After:  ['i', 'purchased', 'this', 'and', 'within', '2', 'days', 'it', 'was', 'no', 'longer', 'working']
# Before:  I wear it everyday and it holds up very well.
# After:  ['i', 'wear', 'it', 'everyday', 'and', 'it', 'holds', 'up', 'very', 'well']
# Before:  Not a good bargain.
# After:  ['not', 'a', 'good', 'bargain']
# Before:  Well packaged, arrived on time, and works as intended.
# After:  ['well', 'packaged', 'arrived', 'on', 'time', 'and', 'works', 'as', 'intended']
# Before:  The battery runs down quickly.
# After:  ['the', 'battery', 'runs', 'down', 'quickly']
# Before:  This item worked great, but it broke after 6 months of use.
# After:  ['this', 'item', 'worked', 'great', 'but', 'it', 'broke', 'after', '6', 'months', 'of', 'use']
# Before:  The headsets are easy to use and everyone loves them.
# After:  ['the', 'headsets', 'are', 'easy', 'to', 'use', 'and', 'everyone', 'loves', 'them']
# Before:  This phone works great.
# After:  ['this', 'phone', 'works', 'great']
# Before:  The construction of the headsets is poor.
# After:  ['the', 'construction', 'of', 'the', 'headsets', 'is', 'poor']
# Before:  Product was excellent and works better than the verizon one and Boy was it cheaper!
# After:  ['product', 'was', 'excellent', 'and', 'works', 'better', 'than', 'the', 'verizon', 'one', 'and', 'boy', 'was', 'it', 'cheaper']
# Before:  The phone loads super!
# After:  ['the', 'phone', 'loads', 'super']
# Before:  For a product that costs as much as this one does, I expect it to work far better and with greater ease than this thing does.
# After:  ['for', 'a', 'product', 'that', 'costs', 'as', 'much', 'as', 'this', 'one', 'does', 'i', 'expect', 'it', 'to', 'work', 'far', 'better', 'and', 'with', 'greater', 'ease', 'than', 'this', 'thing', 'does']
# Before:  Made very sturdy.
# After:  ['made', 'very', 'sturdy']
# Before:  Worked great!.
# After:  ['worked', 'great']
# Before:  The ear buds only play music in one ear.
# After:  ['the', 'ear', 'buds', 'only', 'play', 'music', 'in', 'one', 'ear']
# Before:  Dont waste your money...
# After:  ['dont', 'waste', 'your', 'money']
# Before:  Will order from them again!
# After:  ['will', 'order', 'from', 'them', 'again']
# Before:  If you plan to use this in a car forget about it.
# After:  ['if', 'you', 'plan', 'to', 'use', 'this', 'in', 'a', 'car', 'forget', 'about', 'it']
# Before:  I found this product to be waaay too big.
# After:  ['i', 'found', 'this', 'product', 'to', 'be', 'waaay', 'too', 'big']
# Before:  Best I've found so far .... I've tried 2 other bluetooths and this one has the best quality (for both me and the listener) as well as ease of using.
# After:  ['best', 'ive', 'found', 'so', 'far', 'ive', 'tried', '2', 'other', 'bluetooths', 'and', 'this', 'one', 'has', 'the', 'best', 'quality', 'for', 'both', 'me', 'and', 'the', 'listener', 'as', 'well', 'as', 'ease', 'of', 'using']
# Before:  I'm very disappointed with my decision.
# After:  ['im', 'very', 'disappointed', 'with', 'my', 'decision']
# Before:  Integrated seamlessly with the Motorola RAZR phone.
# After:  ['integrated', 'seamlessly', 'with', 'the', 'motorola', 'razr', 'phone']
# Before:  Buyer Beware, you could flush money right down the toilet.
# After:  ['buyer', 'beware', 'you', 'could', 'flush', 'money', 'right', 'down', 'the', 'toilet']
# Before:  Definitely a bargain.
# After:  ['definitely', 'a', 'bargain']
# Before:  The price was very good and with the free shipping and all it was a good purchase.
# After:  ['the', 'price', 'was', 'very', 'good', 'and', 'with', 'the', 'free', 'shipping', 'and', 'all', 'it', 'was', 'a', 'good', 'purchase']
# Before:  I received my supposedly new motorola 375 and apparently there was not a match between the phone and the charger.
# After:  ['i', 'received', 'my', 'supposedly', 'new', 'motorola', '375', 'and', 'apparently', 'there', 'was', 'not', 'a', 'match', 'between', 'the', 'phone', 'and', 'the', 'charger']
# Before:  Pros:-Good camera - very nice pictures , also has cool styles like black and white, and more.
# After:  ['pros:good', 'camera', 'very', 'nice', 'pictures', 'also', 'has', 'cool', 'styles', 'like', 'black', 'and', 'white', 'and', 'more']
# Before:  That's a huge design flaw (unless I'm not using it correctly, which I don't think is the case).
# After:  ['thats', 'a', 'huge', 'design', 'flaw', 'unless', 'im', 'not', 'using', 'it', 'correctly', 'which', 'i', 'dont', 'think', 'is', 'the', 'case']
# Before:  I love my 350 headset.. My Jabra350 bluetooth headset is great, the reception is very good and the ear piece is a comfortable fit.
# After:  ['i', 'love', 'my', '350', 'headset', 'my', 'jabra350', 'bluetooth', 'headset', 'is', 'great', 'the', 'reception', 'is', 'very', 'good', 'and', 'the', 'ear', 'piece', 'is', 'a', 'comfortable', 'fit']
# Before:  The camera, although rated at an impressive 1.3 megapixels, renders images that fall well below expectations of such a relatively high resolution.
# After:  ['the', 'camera', 'although', 'rated', 'at', 'an', 'impressive', '13', 'megapixels', 'renders', 'images', 'that', 'fall', 'well', 'below', 'expectations', 'of', 'such', 'a', 'relatively', 'high', 'resolution']
# Before:  I purcashed this for the car charger and it does not work.
# After:  ['i', 'purcashed', 'this', 'for', 'the', 'car', 'charger', 'and', 'it', 'does', 'not', 'work']
# Before:  Sound quality on both end is excellent, I use headset to call my wife and ask my wife to use headset to call me !2.
# After:  ['sound', 'quality', 'on', 'both', 'end', 'is', 'excellent', 'i', 'use', 'headset', 'to', 'call', 'my', 'wife', 'and', 'ask', 'my', 'wife', 'to', 'use', 'headset', 'to', 'call', 'me', '2']
# Before:  This phone is slim and light and the display is beautiful.
# After:  ['this', 'phone', 'is', 'slim', 'and', 'light', 'and', 'the', 'display', 'is', 'beautiful']
# Before:  its a little geeky but i think thats its sex on toast and it rocks and oozes sex right down to its battery embedded sleek stylish leather case.
# After:  ['its', 'a', 'little', 'geeky', 'but', 'i', 'think', 'thats', 'its', 'sex', 'on', 'toast', 'and', 'it', 'rocks', 'and', 'oozes', 'sex', 'right', 'down', 'to', 'its', 'battery', 'embedded', 'sleek', 'stylish', 'leather', 'case']
# Before:  Great product, fast shipping!.
# After:  ['great', 'product', 'fast', 'shipping']
# Before:  Absolutely great.
# After:  ['absolutely', 'great']
# Before:  The keyboard is a nice compromise between a full QWERTY and the basic cell phone number keypad.
# After:  ['the', 'keyboard', 'is', 'a', 'nice', 'compromise', 'between', 'a', 'full', 'qwerty', 'and', 'the', 'basic', 'cell', 'phone', 'number', 'keypad']
# Before:  i got this phone around the end of may and i'm completely unhappy with it.
# After:  ['i', 'got', 'this', 'phone', 'around', 'the', 'end', 'of', 'may', 'and', 'im', 'completely', 'unhappy', 'with', 'it']
# Before:  It is very comfortable on the ear.
# After:  ['it', 'is', 'very', 'comfortable', 'on', 'the', 'ear']
# Before:  It has been a winner for us.
# After:  ['it', 'has', 'been', 'a', 'winner', 'for', 'us']
# Before:  )Setup couldn't have been simpler.
# After:  ['setup', 'couldnt', 'have', 'been', 'simpler']
# Before:  I've tried several different earpieces for my cell phone and this Jabra one is the first one I've found that fits my ear comfortably.
# After:  ['ive', 'tried', 'several', 'different', 'earpieces', 'for', 'my', 'cell', 'phone', 'and', 'this', 'jabra', 'one', 'is', 'the', 'first', 'one', 'ive', 'found', 'that', 'fits', 'my', 'ear', 'comfortably']
# Before:  Could not get strong enough signal.
# After:  ['could', 'not', 'get', 'strong', 'enough', 'signal']
# Before:  Iam very pleased with my purchase.
# After:  ['iam', 'very', 'pleased', 'with', 'my', 'purchase']
# Before:  Bad Quality.
# After:  ['bad', 'quality']
# Before:  Gets the job done.
# After:  ['gets', 'the', 'job', 'done']
# Before:  Great audio!.
# After:  ['great', 'audio']
# Before:  Basically the service was very bad.
# After:  ['basically', 'the', 'service', 'was', 'very', 'bad']
# Before:  it did not work in my cell phone plug i am very up set with the charger!.
# After:  ['it', 'did', 'not', 'work', 'in', 'my', 'cell', 'phone', 'plug', 'i', 'am', 'very', 'up', 'set', 'with', 'the', 'charger']
# Before:  I've only had my bluetooth for a few weeks, but I really like it.
# After:  ['ive', 'only', 'had', 'my', 'bluetooth', 'for', 'a', 'few', 'weeks', 'but', 'i', 'really', 'like', 'it']
# Before:  The BT headset was such a disapoinment.
# After:  ['the', 'bt', 'headset', 'was', 'such', 'a', 'disapoinment']
# Before:  It is so small and you don't even realize that it is there after a while of getting used to it.
# After:  ['it', 'is', 'so', 'small', 'and', 'you', 'dont', 'even', 'realize', 'that', 'it', 'is', 'there', 'after', 'a', 'while', 'of', 'getting', 'used', 'to', 'it']
# Before:  The accompanied software is almost brilliant.
# After:  ['the', 'accompanied', 'software', 'is', 'almost', 'brilliant']
# Before:  Headset works great & was packaged nicely to avoid any damage.
# After:  ['headset', 'works', 'great', 'was', 'packaged', 'nicely', 'to', 'avoid', 'any', 'damage']
# Before:  !I definitly recommend!!
# After:  ['i', 'definitly', 'recommend']
# Before:  Buyer--Be Very Careful!!!!!.
# After:  ['buyerbe', 'very', 'careful']
# Before:  The majority of the Logitech earbud headsets failed.
# After:  ['the', 'majority', 'of', 'the', 'logitech', 'earbud', 'headsets', 'failed']
# Before:  Very good stuff for the price.
# After:  ['very', 'good', 'stuff', 'for', 'the', 'price']
# Before:  My headset works just peachy-keen.
# After:  ['my', 'headset', 'works', 'just', 'peachykeen']
# Before:  In my house I was getting dropped coverage upstairs and no coverage in my basement.
# After:  ['in', 'my', 'house', 'i', 'was', 'getting', 'dropped', 'coverage', 'upstairs', 'and', 'no', 'coverage', 'in', 'my', 'basement']
# Before:  Voice recognition is tremendous!
# After:  ['voice', 'recognition', 'is', 'tremendous']
# Before:  What a waste.
# After:  ['what', 'a', 'waste']
# Before:  During several different 2 minute calls, I experienced 5 drops and it was in an area that had 5 bars.
# After:  ['during', 'several', 'different', '2', 'minute', 'calls', 'i', 'experienced', '5', 'drops', 'and', 'it', 'was', 'in', 'an', 'area', 'that', 'had', '5', 'bars']
# Before:  I was not happy with this item.
# After:  ['i', 'was', 'not', 'happy', 'with', 'this', 'item']
# Before:  very disappointed.
# After:  ['very', 'disappointed']
# Before:  The phone takes FOREVER to charge like 2 to 5 hours literally.
# After:  ['the', 'phone', 'takes', 'forever', 'to', 'charge', 'like', '2', 'to', '5', 'hours', 'literally']
# Before:  I got this phone on reccomendation from a relative and I'm glad I did.
# After:  ['i', 'got', 'this', 'phone', 'on', 'reccomendation', 'from', 'a', 'relative', 'and', 'im', 'glad', 'i', 'did']
# Before:  What a waste of time!
# After:  ['what', 'a', 'waste', 'of', 'time']
# Before:  Its reception is very very poor.
# After:  ['its', 'reception', 'is', 'very', 'very', 'poor']
# Before:  Items stated as included from the description ARE NOT INCLUDED.
# After:  ['items', 'stated', 'as', 'included', 'from', 'the', 'description', 'are', 'not', 'included']
# Before:  After 3 months, screen just went black all of a sudden.
# After:  ['after', '3', 'months', 'screen', 'just', 'went', 'black', 'all', 'of', 'a', 'sudden']
# Before:  I Was Hoping for More.
# After:  ['i', 'was', 'hoping', 'for', 'more']
# Before:  Audio Quality is poor, very poor.
# After:  ['audio', 'quality', 'is', 'poor', 'very', 'poor']
# Before:  I had absolutely no problem with this headset linking to my 8530 Blackberry Curve!
# After:  ['i', 'had', 'absolutely', 'no', 'problem', 'with', 'this', 'headset', 'linking', 'to', 'my', '8530', 'blackberry', 'curve']
# Before:  I know that sounds funny, but to me it seemed like sketchy technology that wouldn't work well.Well, this one works great.
# After:  ['i', 'know', 'that', 'sounds', 'funny', 'but', 'to', 'me', 'it', 'seemed', 'like', 'sketchy', 'technology', 'that', 'wouldnt', 'work', 'wellwell', 'this', 'one', 'works', 'great']
# Before:  I've bought $5 wired headphones that sound better than these.
# After:  ['ive', 'bought', '5', 'wired', 'headphones', 'that', 'sound', 'better', 'than', 'these']
# Before:  This phone is very fast with sending any kind of messages and web browsing is significantly faster than previous phones i have used.
# After:  ['this', 'phone', 'is', 'very', 'fast', 'with', 'sending', 'any', 'kind', 'of', 'messages', 'and', 'web', 'browsing', 'is', 'significantly', 'faster', 'than', 'previous', 'phones', 'i', 'have', 'used']
# Before:  Nice quality build, unlike some cheap s*** out there.
# After:  ['nice', 'quality', 'build', 'unlike', 'some', 'cheap', 's', 'out', 'there']
# Before:  This item is fantastic and works perfectly!
# After:  ['this', 'item', 'is', 'fantastic', 'and', 'works', 'perfectly']
# Before:  And I just love the colors!
# After:  ['and', 'i', 'just', 'love', 'the', 'colors']
# Before:  W810i is just SUPERB.
# After:  ['w810i', 'is', 'just', 'superb']
# Before:  All I can do is whine on the Internet, so here it goes.The more I use the thing the less I like it.
# After:  ['all', 'i', 'can', 'do', 'is', 'whine', 'on', 'the', 'internet', 'so', 'here', 'it', 'goesthe', 'more', 'i', 'use', 'the', 'thing', 'the', 'less', 'i', 'like', 'it']
# Before:  Great charger.
# After:  ['great', 'charger']
# Before:  This is essentially a communications tool that does not communicate.
# After:  ['this', 'is', 'essentially', 'a', 'communications', 'tool', 'that', 'does', 'not', 'communicate']
# Before:  Works like a charm; it work the same as the one I got with the phone.
# After:  ['works', 'like', 'a', 'charm', 'it', 'work', 'the', 'same', 'as', 'the', 'one', 'i', 'got', 'with', 'the', 'phone']
# Before:  I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans.
# After:  ['i', 'still', 'maintain', 'that', 'monkeys', 'shouldnt', 'make', 'headphones', 'we', 'just', 'obviously', 'dont', 'share', 'enough', 'dna', 'to', 'copy', 'the', 'design', 'over', 'to', 'humans']
# Before:  Great Value.
# After:  ['great', 'value']
# Before:  Doesn't work at all.. I bougth it for my L7c and its not working.
# After:  ['doesnt', 'work', 'at', 'all', 'i', 'bougth', 'it', 'for', 'my', 'l7c', 'and', 'its', 'not', 'working']
# Before:  The look of it is very sharp and the screen is nice and clear, with great graphics.
# After:  ['the', 'look', 'of', 'it', 'is', 'very', 'sharp', 'and', 'the', 'screen', 'is', 'nice', 'and', 'clear', 'with', 'great', 'graphics']
# Before:  doesn't last long.
# After:  ['doesnt', 'last', 'long']
# Before:  One thing I hate is the mode set button at the side.
# After:  ['one', 'thing', 'i', 'hate', 'is', 'the', 'mode', 'set', 'button', 'at', 'the', 'side']
# Before:  EXCELLENT SERVICE!!!!!!!!.
# After:  ['excellent', 'service']
# Before:  Thank you for wasting my money.
# After:  ['thank', 'you', 'for', 'wasting', 'my', 'money']
# Before:  How can that be?The audio quality is poor.
# After:  ['how', 'can', 'that', 'bethe', 'audio', 'quality', 'is', 'poor']
# Before:  The iGo chargers and tips are really great.
# After:  ['the', 'igo', 'chargers', 'and', 'tips', 'are', 'really', 'great']
# Before:  The file browser offers all the options that one needs.Handsfree is great.
# After:  ['the', 'file', 'browser', 'offers', 'all', 'the', 'options', 'that', 'one', 'needshandsfree', 'is', 'great']
# Before:  Superb Phone on a Great Network.
# After:  ['superb', 'phone', 'on', 'a', 'great', 'network']
# Before:  I connected my wife's bluetooth,(Motorola HS850) to my phone and it worked like a charm whether the phone was in my pocket or the case.
# After:  ['i', 'connected', 'my', 'wifes', 'bluetoothmotorola', 'hs850', 'to', 'my', 'phone', 'and', 'it', 'worked', 'like', 'a', 'charm', 'whether', 'the', 'phone', 'was', 'in', 'my', 'pocket', 'or', 'the', 'case']
# Before:  I put the latest OS on it (v1.15g), and it now likes to slow to a crawl and lock up every once in a while.
# After:  ['i', 'put', 'the', 'latest', 'os', 'on', 'it', 'v115g', 'and', 'it', 'now', 'likes', 'to', 'slow', 'to', 'a', 'crawl', 'and', 'lock', 'up', 'every', 'once', 'in', 'a', 'while']
# Before:  It only recognizes the Phone as its storage device.
# After:  ['it', 'only', 'recognizes', 'the', 'phone', 'as', 'its', 'storage', 'device']
# Before:  If you like a loud buzzing to override all your conversations, then this phone is for you!
# After:  ['if', 'you', 'like', 'a', 'loud', 'buzzing', 'to', 'override', 'all', 'your', 'conversations', 'then', 'this', 'phone', 'is', 'for', 'you']
# Before:  Don't buy this product.
# After:  ['dont', 'buy', 'this', 'product']
# Before:  I've had this bluetoooth headset for some time now and still not comfortable with the way it fits on the ear.
# After:  ['ive', 'had', 'this', 'bluetoooth', 'headset', 'for', 'some', 'time', 'now', 'and', 'still', 'not', 'comfortable', 'with', 'the', 'way', 'it', 'fits', 'on', 'the', 'ear']
# Before:  The sound quality is good and functionality is awesome.
# After:  ['the', 'sound', 'quality', 'is', 'good', 'and', 'functionality', 'is', 'awesome']
# Before:  I have this phone and it is a thorn in my side, I really abhor it.
# After:  ['i', 'have', 'this', 'phone', 'and', 'it', 'is', 'a', 'thorn', 'in', 'my', 'side', 'i', 'really', 'abhor', 'it']
# Before:  I recently had problems where I could not stay connected for more than 10 minutes before being disconnected.
# After:  ['i', 'recently', 'had', 'problems', 'where', 'i', 'could', 'not', 'stay', 'connected', 'for', 'more', 'than', '10', 'minutes', 'before', 'being', 'disconnected']
# Before:  Incredible!.
# After:  ['incredible']
# Before:  Design Flaw?.
# After:  ['design', 'flaw']
# Before:  Great phone!.
# After:  ['great', 'phone']
# Before:  Waste of 13 bucks.
# After:  ['waste', 'of', '13', 'bucks']
# Before:  But when I check voice mail at night, the keypad backlight turns off a few seconds into the first message, and then I'm lost.
# After:  ['but', 'when', 'i', 'check', 'voice', 'mail', 'at', 'night', 'the', 'keypad', 'backlight', 'turns', 'off', 'a', 'few', 'seconds', 'into', 'the', 'first', 'message', 'and', 'then', 'im', 'lost']
# Before:  The replacement died in a few weeks.
# After:  ['the', 'replacement', 'died', 'in', 'a', 'few', 'weeks']
# Before:  Any ring tone..Overall good phone to buy..
# After:  ['any', 'ring', 'toneoverall', 'good', 'phone', 'to', 'buy']
# Before:  Lately they have been extremely nice and helpful on the phone.
# After:  ['lately', 'they', 'have', 'been', 'extremely', 'nice', 'and', 'helpful', 'on', 'the', 'phone']
# Before:  I have had problems wit hit dropping signal and more.
# After:  ['i', 'have', 'had', 'problems', 'wit', 'hit', 'dropping', 'signal', 'and', 'more']
# Before:  Not impressed.
# After:  ['not', 'impressed']
# Before:  Light weight, I hardly notice it is there.
# After:  ['light', 'weight', 'i', 'hardly', 'notice', 'it', 'is', 'there']
# Before:  You'll love how thin it is.
# After:  ['youll', 'love', 'how', 'thin', 'it', 'is']
# Before:  Bad Choice.
# After:  ['bad', 'choice']
# Before:  The pleather case doesn't fit.
# After:  ['the', 'pleather', 'case', 'doesnt', 'fit']
# Before:  useless phone, simply deaf.
# After:  ['useless', 'phone', 'simply', 'deaf']
# Before:  The color is even prettier than I thought it would be, and the graphics are incredibly sharp.
# After:  ['the', 'color', 'is', 'even', 'prettier', 'than', 'i', 'thought', 'it', 'would', 'be', 'and', 'the', 'graphics', 'are', 'incredibly', 'sharp']
# Before:  All in all I think it was a good investment.
# After:  ['all', 'in', 'all', 'i', 'think', 'it', 'was', 'a', 'good', 'investment']
# Before:  It makes very strange ticking noises before it ends the call.
# After:  ['it', 'makes', 'very', 'strange', 'ticking', 'noises', 'before', 'it', 'ends', 'the', 'call']
# Before:  The best electronics of the available FM Transmitters.
# After:  ['the', 'best', 'electronics', 'of', 'the', 'available', 'fm', 'transmitters']
# Before:  Battery lasts only a few hours.
# After:  ['battery', 'lasts', 'only', 'a', 'few', 'hours']
# Before:  great headset, very impressed - H500.
# After:  ['great', 'headset', 'very', 'impressed', 'h500']
# Before:  The "1.2" mega pixel camera, being a part of a phone, is reasonably good7.
# After:  ['the', '12', 'mega', 'pixel', 'camera', 'being', 'a', 'part', 'of', 'a', 'phone', 'is', 'reasonably', 'good7']
# Before:  I've had this for nearly 2 years and it has worked great for me.
# After:  ['ive', 'had', 'this', 'for', 'nearly', '2', 'years', 'and', 'it', 'has', 'worked', 'great', 'for', 'me']
# Before:  Good transmit audio.
# After:  ['good', 'transmit', 'audio']
# Before:  We are sending it back.
# After:  ['we', 'are', 'sending', 'it', 'back']
# Before:  I did not bother contacting the company for few dollar product but I learned the lesson that I should not have bought this form online anyway.
# After:  ['i', 'did', 'not', 'bother', 'contacting', 'the', 'company', 'for', 'few', 'dollar', 'product', 'but', 'i', 'learned', 'the', 'lesson', 'that', 'i', 'should', 'not', 'have', 'bought', 'this', 'form', 'online', 'anyway']
# Before:  If you hate earbugs, avoid this phone by all means.
# After:  ['if', 'you', 'hate', 'earbugs', 'avoid', 'this', 'phone', 'by', 'all', 'means']
# Before:  Great price also!
# After:  ['great', 'price', 'also']
# Before:  The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues.
# After:  ['the', 'range', 'is', 'very', 'decent', 'ive', 'been', 'able', 'to', 'roam', 'around', 'my', 'house', 'with', 'the', 'phone', 'in', 'the', 'living', 'room', 'with', 'no', 'receptionsound', 'quality', 'issues']
# Before:  fast service.
# After:  ['fast', 'service']
# Before:  I would highly recommend this.
# After:  ['i', 'would', 'highly', 'recommend', 'this']
# Before:  I would recommend this.
# After:  ['i', 'would', 'recommend', 'this']
# Before:  I also didn't like the "on" button, it felt like it would crack with use.
# After:  ['i', 'also', 'didnt', 'like', 'the', 'on', 'button', 'it', 'felt', 'like', 'it', 'would', 'crack', 'with', 'use']
# Before:  WORST PHONE EVER.
# After:  ['worst', 'phone', 'ever']
# Before:  I'm still infatuated with this phone.
# After:  ['im', 'still', 'infatuated', 'with', 'this', 'phone']
# Before:  Freezes frequently4.
# After:  ['freezes', 'frequently4']
# Before:  It's kind of embarrassing to use because of how it looks and mostly it's embarrassing how child-like the company is.
# After:  ['its', 'kind', 'of', 'embarrassing', 'to', 'use', 'because', 'of', 'how', 'it', 'looks', 'and', 'mostly', 'its', 'embarrassing', 'how', 'childlike', 'the', 'company', 'is']
# Before:  Simple, lightweight and great fit.
# After:  ['simple', 'lightweight', 'and', 'great', 'fit']
# Before:  All in all, I'd expected a better consumer experience from Motorola.
# After:  ['all', 'in', 'all', 'id', 'expected', 'a', 'better', 'consumer', 'experience', 'from', 'motorola']
# Before:  There's a horrible tick sound in the background on all my calls that I have never experienced before.
# After:  ['theres', 'a', 'horrible', 'tick', 'sound', 'in', 'the', 'background', 'on', 'all', 'my', 'calls', 'that', 'i', 'have', 'never', 'experienced', 'before']
# Before:  These are certainly very comfortable and functionality is decent.
# After:  ['these', 'are', 'certainly', 'very', 'comfortable', 'and', 'functionality', 'is', 'decent']
# Before:  I usually don't like headbands but this one is very lightweight & doesn't mess up my hair.
# After:  ['i', 'usually', 'dont', 'like', 'headbands', 'but', 'this', 'one', 'is', 'very', 'lightweight', 'doesnt', 'mess', 'up', 'my', 'hair']
# Before:  I'm a bit disappointed.
# After:  ['im', 'a', 'bit', 'disappointed']
# Before:  I have had this phone for over a year now, and I will tell you, its not that great.
# After:  ['i', 'have', 'had', 'this', 'phone', 'for', 'over', 'a', 'year', 'now', 'and', 'i', 'will', 'tell', 'you', 'its', 'not', 'that', 'great']
# Before:  I ordered this for sony Ericsson W810i but I think it only worked once (thats when I first used it).
# After:  ['i', 'ordered', 'this', 'for', 'sony', 'ericsson', 'w810i', 'but', 'i', 'think', 'it', 'only', 'worked', 'once', 'thats', 'when', 'i', 'first', 'used', 'it']
# Before:  The battery is completely useless to me.
# After:  ['the', 'battery', 'is', 'completely', 'useless', 'to', 'me']
# Before:  What a big waste of time.
# After:  ['what', 'a', 'big', 'waste', 'of', 'time']
# Before:  Don't waste your $$$ on this one.
# After:  ['dont', 'waste', 'your', 'on', 'this', 'one']
# Before:  Great sound and service.
# After:  ['great', 'sound', 'and', 'service']
# Before:  Really pleased with this product so far.
# After:  ['really', 'pleased', 'with', 'this', 'product', 'so', 'far']
# Before:  One of my favorite purchases ever.
# After:  ['one', 'of', 'my', 'favorite', 'purchases', 'ever']
# Before:  best bluetooth on the market.
# After:  ['best', 'bluetooth', 'on', 'the', 'market']
# Before:  Authentic leather with nice shine and comfort .I recommend you this case !!
# After:  ['authentic', 'leather', 'with', 'nice', 'shine', 'and', 'comfort', 'i', 'recommend', 'you', 'this', 'case']
# Before:  I was very excited to get this headset because I thought it was really cute.
# After:  ['i', 'was', 'very', 'excited', 'to', 'get', 'this', 'headset', 'because', 'i', 'thought', 'it', 'was', 'really', 'cute']
# Before:  Do not make the same mistake as me.
# After:  ['do', 'not', 'make', 'the', 'same', 'mistake', 'as', 'me']
# Before:  Big Disappointment with calendar sync.
# After:  ['big', 'disappointment', 'with', 'calendar', 'sync']
# Before:  the phone was unusable and was not new.
# After:  ['the', 'phone', 'was', 'unusable', 'and', 'was', 'not', 'new']
# Before:  Worst Customer Service Ever.
# After:  ['worst', 'customer', 'service', 'ever']
# Before:  No additional ear gels provided, and no instructions whatsoever.
# After:  ['no', 'additional', 'ear', 'gels', 'provided', 'and', 'no', 'instructions', 'whatsoever']
# Before:  It defeats the purpose of a bluetooth headset.
# After:  ['it', 'defeats', 'the', 'purpose', 'of', 'a', 'bluetooth', 'headset']
# Before:  Worth every penny.
# After:  ['worth', 'every', 'penny']
# Before:  Excellent wallet type phone case.
# After:  ['excellent', 'wallet', 'type', 'phone', 'case']
# Before:  Nice headphones for the price and they work great!
# After:  ['nice', 'headphones', 'for', 'the', 'price', 'and', 'they', 'work', 'great']
# Before:  Internet is excrutiatingly slow.
# After:  ['internet', 'is', 'excrutiatingly', 'slow']
# Before:  It is very comfortable to wear as well, which is probably the most important aspect about using a case.
# After:  ['it', 'is', 'very', 'comfortable', 'to', 'wear', 'as', 'well', 'which', 'is', 'probably', 'the', 'most', 'important', 'aspect', 'about', 'using', 'a', 'case']
# Before:  It's fits like a glove and is strong, secure, and durable.
# After:  ['its', 'fits', 'like', 'a', 'glove', 'and', 'is', 'strong', 'secure', 'and', 'durable']
# Before:  O my gosh the best phone I have ever had.
# After:  ['o', 'my', 'gosh', 'the', 'best', 'phone', 'i', 'have', 'ever', 'had']
# Before:  It's very attractive and appears to be of good quality.
# After:  ['its', 'very', 'attractive', 'and', 'appears', 'to', 'be', 'of', 'good', 'quality']
# Before:  I love all the features and form factor.
# After:  ['i', 'love', 'all', 'the', 'features', 'and', 'form', 'factor']
# Before:  This product had a strong rubber/petroleum smell that was unbearable after a while and caused me to return it
# After:  ['this', 'product', 'had', 'a', 'strong', 'rubberpetroleum', 'smell', 'that', 'was', 'unbearable', 'after', 'a', 'while', 'and', 'caused', 'me', 'to', 'return', 'it']
# Before:  poor quality and service.
# After:  ['poor', 'quality', 'and', 'service']
# Before:  The cable looks so thin and flimsy, it is scary.
# After:  ['the', 'cable', 'looks', 'so', 'thin', 'and', 'flimsy', 'it', 'is', 'scary']
# Before:  Great Earpiece.
# After:  ['great', 'earpiece']
# Before:  Excellent hands free tool.
# After:  ['excellent', 'hands', 'free', 'tool']
# Before:  Great for using with your home stereo.
# After:  ['great', 'for', 'using', 'with', 'your', 'home', 'stereo']
# Before:  Good product - incredible value.
# After:  ['good', 'product', 'incredible', 'value']
# Before:  Only had this a month but it's worked flawlessly so far.
# After:  ['only', 'had', 'this', 'a', 'month', 'but', 'its', 'worked', 'flawlessly', 'so', 'far']
# Before:  Works great.
# After:  ['works', 'great']
# Before:  Absolutel junk.
# After:  ['absolutel', 'junk']
# Before:  THAT one didn't work either.
# After:  ['that', 'one', 'didnt', 'work', 'either']
# Before:  Battery life is real good.
# After:  ['battery', 'life', 'is', 'real', 'good']
# Before:  Returned 8 hours later.
# After:  ['returned', '8', 'hours', 'later']
# Before:  It's a great item.
# After:  ['its', 'a', 'great', 'item']
# Before:  Don't waste your money!.
# After:  ['dont', 'waste', 'your', 'money']
# Before:  Love this headset!
# After:  ['love', 'this', 'headset']
# Before:  Not only will it drain your player, but may also potentially fry it.
# After:  ['not', 'only', 'will', 'it', 'drain', 'your', 'player', 'but', 'may', 'also', 'potentially', 'fry', 'it']
# Before:  Worked perfectly!
# After:  ['worked', 'perfectly']
# Before:  Unreliable - I'm giving up.
# After:  ['unreliable', 'im', 'giving', 'up']
# Before:  I gave it 5 stars because of the sound quality.
# After:  ['i', 'gave', 'it', '5', 'stars', 'because', 'of', 'the', 'sound', 'quality']
# Before:  Avoid this one if you can.
# After:  ['avoid', 'this', 'one', 'if', 'you', 'can']
# Before:  Reversible plug works great.
# After:  ['reversible', 'plug', 'works', 'great']
# Before:  I wasted my little money with this earpiece.
# After:  ['i', 'wasted', 'my', 'little', 'money', 'with', 'this', 'earpiece']
# Before:  Very good phone.
# After:  ['very', 'good', 'phone']
# Before:  Best of all is the rotating feature, very helpful.
# After:  ['best', 'of', 'all', 'is', 'the', 'rotating', 'feature', 'very', 'helpful']
# Before:  Comfort for our whole family.
# After:  ['comfort', 'for', 'our', 'whole', 'family']
# Before:  Good product, good seller.
# After:  ['good', 'product', 'good', 'seller']
# Before:  I love this bluetooth!
# After:  ['i', 'love', 'this', 'bluetooth']
# Before:  First of all, it doesn't wear well.
# After:  ['first', 'of', 'all', 'it', 'doesnt', 'wear', 'well']
# Before:  I am very impressed with this headset from Plantronics.
# After:  ['i', 'am', 'very', 'impressed', 'with', 'this', 'headset', 'from', 'plantronics']
# Before:  I got it because it was so small and adorable.
# After:  ['i', 'got', 'it', 'because', 'it', 'was', 'so', 'small', 'and', 'adorable']
# Before:  Great phone!.
# After:  ['great', 'phone']
# Before:  I wouldn't recommend buying this product.
# After:  ['i', 'wouldnt', 'recommend', 'buying', 'this', 'product']
# Before:  Piece of Junk.
# After:  ['piece', 'of', 'junk']
# Before:  Poorly contstruct hinge.
# After:  ['poorly', 'contstruct', 'hinge']
# Before:  This item is great, installed it, let it charged up overnite and it has been working good every since with no problems
# After:  ['this', 'item', 'is', 'great', 'installed', 'it', 'let', 'it', 'charged', 'up', 'overnite', 'and', 'it', 'has', 'been', 'working', 'good', 'every', 'since', 'with', 'no', 'problems']
# Before:  Great Phone.
# After:  ['great', 'phone']
# Before:  Don't buy it.
# After:  ['dont', 'buy', 'it']
# Before:  Excellent Phone.
# After:  ['excellent', 'phone']
# Before:  DO NOT PURCHASE THIS PHONE.
# After:  ['do', 'not', 'purchase', 'this', 'phone']
# Before:  The voice recognition thru the handset is excellent.
# After:  ['the', 'voice', 'recognition', 'thru', 'the', 'handset', 'is', 'excellent']
# Before:  This is hands down the best phone I've ever had.
# After:  ['this', 'is', 'hands', 'down', 'the', 'best', 'phone', 'ive', 'ever', 'had']
# Before:  Works great, when my cat attacked the phone he scratched the protective strip instead of destroying the screen.
# After:  ['works', 'great', 'when', 'my', 'cat', 'attacked', 'the', 'phone', 'he', 'scratched', 'the', 'protective', 'strip', 'instead', 'of', 'destroying', 'the', 'screen']
# Before:  This one works and was priced right.
# After:  ['this', 'one', 'works', 'and', 'was', 'priced', 'right']
# Before:  Customer service was terrible.
# After:  ['customer', 'service', 'was', 'terrible']
# Before:  Battery life still not long enough in Motorola Razor V3i.
# After:  ['battery', 'life', 'still', 'not', 'long', 'enough', 'in', 'motorola', 'razor', 'v3i']
# Before:  Sending it back.
# After:  ['sending', 'it', 'back']
# Before:  Now I know that I made a wise decision.
# After:  ['now', 'i', 'know', 'that', 'i', 'made', 'a', 'wise', 'decision']
# Before:  Someone shouldve invented this sooner.
# After:  ['someone', 'shouldve', 'invented', 'this', 'sooner']
# Before:  Good price.
# After:  ['good', 'price']
# Before:  Everything worked on the first try.The device was certainly engineered in a clever way and the construction feels good.
# After:  ['everything', 'worked', 'on', 'the', 'first', 'trythe', 'device', 'was', 'certainly', 'engineered', 'in', 'a', 'clever', 'way', 'and', 'the', 'construction', 'feels', 'good']
# Before:  I received it quickly and it works great!!
# After:  ['i', 'received', 'it', 'quickly', 'and', 'it', 'works', 'great']
# Before:  Has been working great.
# After:  ['has', 'been', 'working', 'great']
# Before:  As many people complained, I found this headset's microphone was very weak.
# After:  ['as', 'many', 'people', 'complained', 'i', 'found', 'this', 'headsets', 'microphone', 'was', 'very', 'weak']
# Before:  My 5-year old Nokia 2160 from Tracfone holds the charge a lot better than this.
# After:  ['my', '5year', 'old', 'nokia', '2160', 'from', 'tracfone', 'holds', 'the', 'charge', 'a', 'lot', 'better', 'than', 'this']
# Before:  They do not care about the consumer one bit.
# After:  ['they', 'do', 'not', 'care', 'about', 'the', 'consumer', 'one', 'bit']
# Before:  This is a good battery, and it got here really fast.
# After:  ['this', 'is', 'a', 'good', 'battery', 'and', 'it', 'got', 'here', 'really', 'fast']
# Before:  The instruction manual is lacking.
# After:  ['the', 'instruction', 'manual', 'is', 'lacking']
# Before:  Also its slim enough to fit into my alarm clock docking station without removing the case.
# After:  ['also', 'its', 'slim', 'enough', 'to', 'fit', 'into', 'my', 'alarm', 'clock', 'docking', 'station', 'without', 'removing', 'the', 'case']
# Before:  Phone now holds charge like it did when it was new.
# After:  ['phone', 'now', 'holds', 'charge', 'like', 'it', 'did', 'when', 'it', 'was', 'new']
# Before:  The battery is unreliable as well as the service use antena.
# After:  ['the', 'battery', 'is', 'unreliable', 'as', 'well', 'as', 'the', 'service', 'use', 'antena']
# Before:  It's uncomfortable and the sound quality is quite poor compared with the phone (Razr) or with my previous wired headset (that plugged into an LG).
# After:  ['its', 'uncomfortable', 'and', 'the', 'sound', 'quality', 'is', 'quite', 'poor', 'compared', 'with', 'the', 'phone', 'razr', 'or', 'with', 'my', 'previous', 'wired', 'headset', 'that', 'plugged', 'into', 'an', 'lg']
# Before:  We have gotten a lot of compliments on it.
# After:  ['we', 'have', 'gotten', 'a', 'lot', 'of', 'compliments', 'on', 'it']
# ...
# After:  ['the', 'pairing', 'of', 'the', 'two', 'devices', 'was', 'so', 'easy', 'it', 'barely', 'took', 'a', 'couple', 'minutes', 'before', 'i', 'started', 'making', 'calls', 'with', 'the', 'voice', 'dialing', 'feature']
# Before:  This was utterly confusing at first, which caused me to lose a couple of very, very important contacts.
# After:  ['this', 'was', 'utterly', 'confusing', 'at', 'first', 'which', 'caused', 'me', 'to', 'lose', 'a', 'couple', 'of', 'very', 'very', 'important', 'contacts']
# Before:  Terrible phone holder.
# After:  ['terrible', 'phone', 'holder']
# Before:  The cutouts and buttons are placed perfectly.
# After:  ['the', 'cutouts', 'and', 'buttons', 'are', 'placed', 'perfectly']
# Before:  I love being able to use one headset for both by land-line and cell.
# After:  ['i', 'love', 'being', 'able', 'to', 'use', 'one', 'headset', 'for', 'both', 'by', 'landline', 'and', 'cell']
# Before:  Problem is that the ear loops are made of weak material and break easily.
# After:  ['problem', 'is', 'that', 'the', 'ear', 'loops', 'are', 'made', 'of', 'weak', 'material', 'and', 'break', 'easily']
# Before:  Not nearly as good looking as the AMAZON picture makes it look.
# After:  ['not', 'nearly', 'as', 'good', 'looking', 'as', 'the', 'amazon', 'picture', 'makes', 'it', 'look']
# Before:  But despite these few flaws, this case is of exceptional quality and well worth the additional costs of owning an official OEM product.
# After:  ['but', 'despite', 'these', 'few', 'flaws', 'this', 'case', 'is', 'of', 'exceptional', 'quality', 'and', 'well', 'worth', 'the', 'additional', 'costs', 'of', 'owning', 'an', 'official', 'oem', 'product']
# Before:  How stupid is that?
# After:  ['how', 'stupid', 'is', 'that']
# Before:  I can hear while I'm driving in the car, and usually don't even have to put it on it's loudest setting.
# After:  ['i', 'can', 'hear', 'while', 'im', 'driving', 'in', 'the', 'car', 'and', 'usually', 'dont', 'even', 'have', 'to', 'put', 'it', 'on', 'its', 'loudest', 'setting']
# Before:  Seller shipped quickly and much cheaper than the competitors.
# After:  ['seller', 'shipped', 'quickly', 'and', 'much', 'cheaper', 'than', 'the', 'competitors']
# Before:  Good show, Samsung.
# After:  ['good', 'show', 'samsung']
# Before:  So I bought about 10 of these and saved alot of money.
# After:  ['so', 'i', 'bought', 'about', '10', 'of', 'these', 'and', 'saved', 'alot', 'of', 'money']
# Before:  It always cuts out and makes a beep beep beep sound then says signal failed.
# After:  ['it', 'always', 'cuts', 'out', 'and', 'makes', 'a', 'beep', 'beep', 'beep', 'sound', 'then', 'says', 'signal', 'failed']
# Before:  Couldn't figure it out
# After:  ['couldnt', 'figure', 'it', 'out']
# Before:  My phone sounded OK ( not great - OK), but my wife's phone was almost totally unintelligible, she couldn't understand a word being said on it.
# After:  ['my', 'phone', 'sounded', 'ok', 'not', 'great', 'ok', 'but', 'my', 'wifes', 'phone', 'was', 'almost', 'totally', 'unintelligible', 'she', 'couldnt', 'understand', 'a', 'word', 'being', 'said', 'on', 'it']
# Before:  So I had to take the battery out of the phone put it all back together and then restart it.
# After:  ['so', 'i', 'had', 'to', 'take', 'the', 'battery', 'out', 'of', 'the', 'phone', 'put', 'it', 'all', 'back', 'together', 'and', 'then', 'restart', 'it']
# Before:  While I managed to bend the leaf spring back in place, the metal now has enough stress that it will break on the next drop.
# After:  ['while', 'i', 'managed', 'to', 'bend', 'the', 'leaf', 'spring', 'back', 'in', 'place', 'the', 'metal', 'now', 'has', 'enough', 'stress', 'that', 'it', 'will', 'break', 'on', 'the', 'next', 'drop']
# Before:  Leopard Print is wonderfully wild!.
# After:  ['leopard', 'print', 'is', 'wonderfully', 'wild']
# Before:  Works for me.
# After:  ['works', 'for', 'me']
# Before:  Saggy, floppy piece of junk.
# After:  ['saggy', 'floppy', 'piece', 'of', 'junk']
# Before:  much better than the hard plastic cases.
# After:  ['much', 'better', 'than', 'the', 'hard', 'plastic', 'cases']
# Before:  It also had a new problem.
# After:  ['it', 'also', 'had', 'a', 'new', 'problem']
# Before:  Happy so far!.
# After:  ['happy', 'so', 'far']
# Before:  cool phone.
# After:  ['cool', 'phone']
# Before:  Works good.
# After:  ['works', 'good']
# Before:  Motorola finally got the voice quality of a bluetooth headset right.
# After:  ['motorola', 'finally', 'got', 'the', 'voice', 'quality', 'of', 'a', 'bluetooth', 'headset', 'right']
# Before:  It looses connection to the phone even when it is within a couple feet between the two.
# After:  ['it', 'looses', 'connection', 'to', 'the', 'phone', 'even', 'when', 'it', 'is', 'within', 'a', 'couple', 'feet', 'between', 'the', 'two']
# Before:  but it is great, i would really recommend it
# After:  ['but', 'it', 'is', 'great', 'i', 'would', 'really', 'recommend', 'it']
# Before:  Makes it easier to keep up with my bluetooth when I'm not wearing it.
# After:  ['makes', 'it', 'easier', 'to', 'keep', 'up', 'with', 'my', 'bluetooth', 'when', 'im', 'not', 'wearing', 'it']
# Before:  As I said above....PRETTY USELESS!
# After:  ['as', 'i', 'said', 'abovepretty', 'useless']
# Before:  Never got it!!!!!
# After:  ['never', 'got', 'it']
# Before:  This pair of headphones is the worst that I have ever had sound-wise.
# After:  ['this', 'pair', 'of', 'headphones', 'is', 'the', 'worst', 'that', 'i', 'have', 'ever', 'had', 'soundwise']
# Before:  [...] down the drain because of a weak snap!
# After:  ['down', 'the', 'drain', 'because', 'of', 'a', 'weak', 'snap']
# Before:  Does not charge the Cingular (ATT) 8525 phone.
# After:  ['does', 'not', 'charge', 'the', 'cingular', 'att', '8525', 'phone']
# Before:  You get extra minutes so that you can carry out the call and not get cut off."
# After:  ['you', 'get', 'extra', 'minutes', 'so', 'that', 'you', 'can', 'carry', 'out', 'the', 'call', 'and', 'not', 'get', 'cut', 'off']
# Before:  However, after about a year, the fliptop started to get loose and wobbly and eventually my screen went black and I couldn't receive and place calls.
# After:  ['however', 'after', 'about', 'a', 'year', 'the', 'fliptop', 'started', 'to', 'get', 'loose', 'and', 'wobbly', 'and', 'eventually', 'my', 'screen', 'went', 'black', 'and', 'i', 'couldnt', 'receive', 'and', 'place', 'calls']
# Before:  I kept catching the cable on the seat and I had to pull the phone out to turn it on an off.
# After:  ['i', 'kept', 'catching', 'the', 'cable', 'on', 'the', 'seat', 'and', 'i', 'had', 'to', 'pull', 'the', 'phone', 'out', 'to', 'turn', 'it', 'on', 'an', 'off']
# Before:  The headset fulfills my requirements so I am happy with my purchase.
# After:  ['the', 'headset', 'fulfills', 'my', 'requirements', 'so', 'i', 'am', 'happy', 'with', 'my', 'purchase']
# Before:  Logitech Bluetooth Headset is a 10!.
# After:  ['logitech', 'bluetooth', 'headset', 'is', 'a', '10']
# Before:  I like the fact that it rests lightly against your ear, rather than inside.
# After:  ['i', 'like', 'the', 'fact', 'that', 'it', 'rests', 'lightly', 'against', 'your', 'ear', 'rather', 'than', 'inside']
# Before:  A lot of websites have been rating this a very good phone and so do I.
# After:  ['a', 'lot', 'of', 'websites', 'have', 'been', 'rating', 'this', 'a', 'very', 'good', 'phone', 'and', 'so', 'do', 'i']
# Before:  I have tried these cables with my computer and my iPod and it works just fine.
# After:  ['i', 'have', 'tried', 'these', 'cables', 'with', 'my', 'computer', 'and', 'my', 'ipod', 'and', 'it', 'works', 'just', 'fine']
# Before:  The mic there is a joke, and the volume is quite low.
# After:  ['the', 'mic', 'there', 'is', 'a', 'joke', 'and', 'the', 'volume', 'is', 'quite', 'low']
# Before:  I'm returning them.
# After:  ['im', 'returning', 'them']
# Before:  I does not maintain a connection with the computer while it is on my lap.
# After:  ['i', 'does', 'not', 'maintain', 'a', 'connection', 'with', 'the', 'computer', 'while', 'it', 'is', 'on', 'my', 'lap']
# Before:  It is easy to turn on and off when you are in the car and the volume controls are quite accessable.
# After:  ['it', 'is', 'easy', 'to', 'turn', 'on', 'and', 'off', 'when', 'you', 'are', 'in', 'the', 'car', 'and', 'the', 'volume', 'controls', 'are', 'quite', 'accessable']
# Before:  I have had mine for about a year and this Christmas I bought some for the rest of the family.
# After:  ['i', 'have', 'had', 'mine', 'for', 'about', 'a', 'year', 'and', 'this', 'christmas', 'i', 'bought', 'some', 'for', 'the', 'rest', 'of', 'the', 'family']
# Before:  Otherwise, easy to install and use, clear sound.
# After:  ['otherwise', 'easy', 'to', 'install', 'and', 'use', 'clear', 'sound']
# Before:  nice leather.
# After:  ['nice', 'leather']
# Before:  I had to purchase a different case.
# After:  ['i', 'had', 'to', 'purchase', 'a', 'different', 'case']
# Before:  It is a joy to use.
# After:  ['it', 'is', 'a', 'joy', 'to', 'use']
# Before:  Very much disappointed with this company.
# After:  ['very', 'much', 'disappointed', 'with', 'this', 'company']
# Before:  Very satisifed with that.
# After:  ['very', 'satisifed', 'with', 'that']
# Before:  It didn't charge for me.
# After:  ['it', 'didnt', 'charge', 'for', 'me']
# Before:  This is the phone to get for 2005.... I just bought my S710a and all I can say is WOW!
# After:  ['this', 'is', 'the', 'phone', 'to', 'get', 'for', '2005', 'i', 'just', 'bought', 'my', 's710a', 'and', 'all', 'i', 'can', 'say', 'is', 'wow']
# Before:  Buttons are too small.
# After:  ['buttons', 'are', 'too', 'small']
# Before:  Just reading on the specs alone makes you say WOW.
# After:  ['just', 'reading', 'on', 'the', 'specs', 'alone', 'makes', 'you', 'say', 'wow']
# Before:  Love it.. Great armband.
# After:  ['love', 'it', 'great', 'armband']
# Before:  I really like this product over the Motorola because it is allot clearer on the ear piece and the mic.
# After:  ['i', 'really', 'like', 'this', 'product', 'over', 'the', 'motorola', 'because', 'it', 'is', 'allot', 'clearer', 'on', 'the', 'ear', 'piece', 'and', 'the', 'mic']
# Before:  However, the keypads are so tinny that I sometimes reach the wrong buttons.
# After:  ['however', 'the', 'keypads', 'are', 'so', 'tinny', 'that', 'i', 'sometimes', 'reach', 'the', 'wrong', 'buttons']
# Before:  I exchanged the sony ericson z500a for this and I'm pretty happy with that decision.
# After:  ['i', 'exchanged', 'the', 'sony', 'ericson', 'z500a', 'for', 'this', 'and', 'im', 'pretty', 'happy', 'with', 'that', 'decision']
# Before:  I was very impressed with the price of the cases.
# After:  ['i', 'was', 'very', 'impressed', 'with', 'the', 'price', 'of', 'the', 'cases']
# Before:  Also makes it easier to hold on to.
# After:  ['also', 'makes', 'it', 'easier', 'to', 'hold', 'on', 'to']
# Before:  I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great!
# After:  ['i', 'use', 'this', 'product', 'in', 'a', 'motor', 'control', 'center', 'where', 'there', 'is', 'a', 'lot', 'of', 'high', 'voltage', 'humming', 'from', 'the', 'equipment', 'and', 'it', 'works', 'great']
# Before:  It's pretty easy.
# After:  ['its', 'pretty', 'easy']
# Before:  I cannot make calls at certain places.
# After:  ['i', 'cannot', 'make', 'calls', 'at', 'certain', 'places']
# Before:  however, my girl was complain that some time the phone doesn't wake up like normal phone does.
# After:  ['however', 'my', 'girl', 'was', 'complain', 'that', 'some', 'time', 'the', 'phone', 'doesnt', 'wake', 'up', 'like', 'normal', 'phone', 'does']
# Before:  Beautiful styling though.
# After:  ['beautiful', 'styling', 'though']
# Before:  This company charge me a restocking fee and still not given me my refund back.
# After:  ['this', 'company', 'charge', 'me', 'a', 'restocking', 'fee', 'and', 'still', 'not', 'given', 'me', 'my', 'refund', 'back']
# Before:  I'm trying to return it for a refund.
# After:  ['im', 'trying', 'to', 'return', 'it', 'for', 'a', 'refund']
# Before:  I plugged it in only to find out not a darn thing worked.
# After:  ['i', 'plugged', 'it', 'in', 'only', 'to', 'find', 'out', 'not', 'a', 'darn', 'thing', 'worked']
# Before:  Excellent product.
# After:  ['excellent', 'product']
# Before:  Earbud piece breaks easily.
# After:  ['earbud', 'piece', 'breaks', 'easily']
# Before:  Lousy product.
# After:  ['lousy', 'product']
# Before:  This phone tries very hard to do everything but fails at it's very ability to be a phone.
# After:  ['this', 'phone', 'tries', 'very', 'hard', 'to', 'do', 'everything', 'but', 'fails', 'at', 'its', 'very', 'ability', 'to', 'be', 'a', 'phone']
# Before:  It is the best charger I have seen on the market yet.
# After:  ['it', 'is', 'the', 'best', 'charger', 'i', 'have', 'seen', 'on', 'the', 'market', 'yet']
# Before:  SWEETEST PHONE!!!
# After:  ['sweetest', 'phone']
# Before:  :-)Oh, the charger seems to work fine.
# After:  [':oh', 'the', 'charger', 'seems', 'to', 'work', 'fine']
# Before:  It fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal.
# After:  ['it', 'fits', 'so', 'securely', 'that', 'the', 'ear', 'hook', 'does', 'not', 'even', 'need', 'to', 'be', 'used', 'and', 'the', 'sound', 'is', 'better', 'directed', 'through', 'your', 'ear', 'canal']
# Before:  Not enough volume.
# After:  ['not', 'enough', 'volume']
# Before:  Echo Problem....Very unsatisfactory
# After:  ['echo', 'problemvery', 'unsatisfactory']
# Before:  you could only take 2 videos at a time and the quality was very poor.
# After:  ['you', 'could', 'only', 'take', '2', 'videos', 'at', 'a', 'time', 'and', 'the', 'quality', 'was', 'very', 'poor']
# Before:  don't waste your money.
# After:  ['dont', 'waste', 'your', 'money']
# Before:  I am going to have to be the first to negatively review this product.
# After:  ['i', 'am', 'going', 'to', 'have', 'to', 'be', 'the', 'first', 'to', 'negatively', 'review', 'this', 'product']
# Before:  Adapter does not provide enough charging current.
# After:  ['adapter', 'does', 'not', 'provide', 'enough', 'charging', 'current']
# Before:  There was so much hype over this phone that I assumed it was the best, my mistake.
# After:  ['there', 'was', 'so', 'much', 'hype', 'over', 'this', 'phone', 'that', 'i', 'assumed', 'it', 'was', 'the', 'best', 'my', 'mistake']
# Before:  You also cannot take pictures with it in the case because the lense is covered.
# After:  ['you', 'also', 'cannot', 'take', 'pictures', 'with', 'it', 'in', 'the', 'case', 'because', 'the', 'lense', 'is', 'covered']
# Before:  Phone falls out easily.
# After:  ['phone', 'falls', 'out', 'easily']
# Before:  It didn't work, people can not hear me when I talk.
# After:  ['it', 'didnt', 'work', 'people', 'can', 'not', 'hear', 'me', 'when', 'i', 'talk']
# Before:  The text messaging feature is really tricky to use.
# After:  ['the', 'text', 'messaging', 'feature', 'is', 'really', 'tricky', 'to', 'use']
# Before:  I'm really disappointed all I have now is a charger that doesn't work.
# After:  ['im', 'really', 'disappointed', 'all', 'i', 'have', 'now', 'is', 'a', 'charger', 'that', 'doesnt', 'work']
# Before:  Painful on the ear.
# After:  ['painful', 'on', 'the', 'ear']
# Before:  Lasted one day and then blew up.
# After:  ['lasted', 'one', 'day', 'and', 'then', 'blew', 'up']
# Before:  disappointed.
# After:  ['disappointed']
# Before:  Kind of flops around.
# After:  ['kind', 'of', 'flops', 'around']
# Before:  The screen does get smudged easily because it touches your ear and face.
# After:  ['the', 'screen', 'does', 'get', 'smudged', 'easily', 'because', 'it', 'touches', 'your', 'ear', 'and', 'face']
# Before:  What a piece of junk.. I lose more calls on this phone.
# After:  ['what', 'a', 'piece', 'of', 'junk', 'i', 'lose', 'more', 'calls', 'on', 'this', 'phone']
# Before:  Item Does Not Match Picture.
# After:  ['item', 'does', 'not', 'match', 'picture']
# Before:  The only thing that disappoint me is the infra red port (irda).
# After:  ['the', 'only', 'thing', 'that', 'disappoint', 'me', 'is', 'the', 'infra', 'red', 'port', 'irda']
# Before:  You can not answer calls with the unit, never worked once!
# After:  ['you', 'can', 'not', 'answer', 'calls', 'with', 'the', 'unit', 'never', 'worked', 'once']
